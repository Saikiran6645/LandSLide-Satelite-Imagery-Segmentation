# %% [markdown]
# # Installation of required libraries and basic setup

# %%
# !pip install tensorflow

# %%
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import h5py
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf

# %%
import os

# %% [markdown]
# # Testing the dataset

# %%
# Testing the dataset 
path_single = r"C:\Users\myada\OneDrive\Desktop\Satelite_Segmentation\TrainData\img\image_1.h5"
path_single_mask = r'C:\Users\myada\OneDrive\Desktop\Satelite_Segmentation\TrainData\mask\mask_1.h5'

# %%
f_data = np.zeros((1, 128,128, 3))
with h5py.File(path_single) as hdf:
    ls = list(hdf.keys())
    print("ls", ls)
    data = np.array(hdf.get('img'))
    print("input data shape:", data.shape)
    plt.imshow(data[:, :, 3:0:-1])
    
    data_red = data[:, :, 3]
    data_green = data[:, :, 2]
    data_blue = data[:, :, 1]
    data_nir = data[:, :, 7]
    data_rgb = data[:, :, 3:0:-1]
    data_ndvi = np.divide(data_nir - data_red,np.add(data_nir, data_red))
    f_data[0, :, :, 0] =data_ndvi
    f_data[0, :, :, 1] = data[:, :, 12]
    f_data[0, :, :, 2] = data[:, :, 13]

    print("data ndvi shape ", data_ndvi.shape, "f_data shape: ", f_data.shape)
    plt.imshow(data_ndvi)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ls ['img']
# input data shape: (128, 128, 14)
# data ndvi shape  (128, 128) f_data shape:  (1, 128, 128, 3)

# %%
with h5py.File(path_single_mask) as hdf:
    ls = list(hdf.keys())
    print("ls", ls)
    data = np.array(hdf.get('mask'))
    print("input data shape:", data.shape)
    plt.imshow(data)
# Out:
# ls ['mask']
# input data shape: (128, 128)

# %% [markdown]
# # Using all dataset

# %%
# path_single = r"data/img/image_10.h5"
# path_single_mask = r'data/mask/mask_1.h5'
TRAIN_PATH = r"C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\\*.h5"
TRAIN_MASK = r'C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\\*.h5'

TRAIN_XX = np.zeros((3799, 128, 128, 6))
TRAIN_YY = np.zeros((3799, 128, 128, 1))
all_train = sorted(glob.glob(TRAIN_PATH))
all_mask = sorted(glob.glob(TRAIN_MASK))

# %% [markdown]
# ## Train with RGB, NDVI, DEM, and Slope

# %%
#testing for google colab GPU
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# ''

# %%
for i, (img, mask) in enumerate(zip(all_train, all_mask)):
    print(i, img, mask)
    with h5py.File(img) as hdf:
        ls = list(hdf.keys())
        data = np.array(hdf.get('img'))

        # assign 0 for the nan value
        data[np.isnan(data)] = 0.000001

        # to normalize the data 
        mid_rgb = data[:, :, 1:4].max() / 2.0
        mid_slope = data[:, :, 12].max() / 2.0
        mid_elevation = data[:, :, 13].max() / 2.0

        # ndvi calculation
        data_red = data[:, :, 3]
        data_nir = data[:, :, 7]
        data_ndvi = np.divide(data_nir - data_red,np.add(data_nir, data_red))
        
        # final array
        TRAIN_XX[i, :, :, 0] = 1 - data[:, :, 3] / mid_rgb  #RED
        TRAIN_XX[i, :, :, 1] = 1 - data[:, :, 2] / mid_rgb #GREEN
        TRAIN_XX[i, :, :, 2] = 1 - data[:, :, 1] / mid_rgb #BLUE
        TRAIN_XX[i, :, :, 3] = data_ndvi #NDVI
        TRAIN_XX[i, :, :, 4] = 1 - data[:, :, 12] / mid_slope #SLOPE
        TRAIN_XX[i, :, :, 5] = 1 - data[:, :, 13] / mid_elevation #ELEVATION
    
    
    with h5py.File(mask) as hdf:
        ls = list(hdf.keys())
        data=np.array(hdf.get('mask'))
        TRAIN_YY[i, :, :, 0] = data
# Out:
# 0 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1.h5
# 1 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_10.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_10.h5
# 2 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_100.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_100.h5
# 3 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1000.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1000.h5
# 4 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1001.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1001.h5
# 5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1002.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1002.h5
# 6 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1003.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1003.h5
# 7 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1004.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1004.h5
# 8 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1005.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1005.h5
# 9 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1006.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1006.h5
# 10 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1007.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1007.h5
# 11 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1008.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1008.h5
# 12 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1009.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1009.h5
# 13 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_101.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_101.h5
# 14 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1010.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1010.h5
# 15 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1011.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1011.h5
# 16 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1012.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1012.h5
# 17 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1013.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1013.h5
# 18 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1014.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1014.h5
# 19 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1015.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1015.h5
# 20 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1016.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1016.h5
# 21 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1017.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1017.h5
# 22 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1018.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_1018.h5
# 23 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_1019.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_
C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_981.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_981.h5
# 3780 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_982.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_982.h5
# 3781 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_983.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_983.h5
# 3782 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_984.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_984.h5
# 3783 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_985.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_985.h5
# 3784 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_986.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_986.h5
# 3785 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_987.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_987.h5
# 3786 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_988.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_988.h5
# 3787 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_989.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_989.h5
# 3788 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_99.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_99.h5
# 3789 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_990.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_990.h5
# 3790 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_991.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_991.h5
# 3791 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_992.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_992.h5
# 3792 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_993.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_993.h5
# 3793 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_994.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_994.h5
# 3794 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_995.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_995.h5
# 3795 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_996.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_996.h5
# 3796 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_997.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_997.h5
# 3797 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_998.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_998.h5
# 3798 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\img\image_999.h5 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\TrainData\\mask\mask_999.h5

# %% [markdown]
# ## Testing min, max values in train data

# %%
# TRAIN_XX_n = TRAIN_XX / TRAIN_XX.max()
TRAIN_XX[np.isnan(TRAIN_XX)] = 0.000001
print(TRAIN_XX.min(), TRAIN_XX.max(), TRAIN_YY.min(), TRAIN_YY.max())
# Out:
# -1.0 1.0 0.0 1.0

# %% [markdown]
# ## Custom loss function (Dice Loss)

# %%
def dice_loss(y_true, y_pred):
  y_true = tf.cast(y_true, tf.float32)
  y_pred = tf.math.sigmoid(y_pred)
  numerator = 2 * tf.reduce_sum(y_true * y_pred)
  denominator = tf.reduce_sum(y_true + y_pred)

  return 1 - numerator / denominator

# %% [markdown]
# ## Visualization of the training data

# %%
img=234
fig,(ax1,ax2, ax3, ax4, ax5)= plt.subplots(1,5,figsize=(15,10))


ax1.set_title("RGB image")
ax2.set_title("NDVI")
ax3.set_title("Slope")
ax4.set_title("Elevation")
ax5.set_title("Mask")
ax1.imshow(TRAIN_XX[img, :, :, 0:3])
ax2.imshow(TRAIN_XX[img, :, :, 3])
ax3.imshow(TRAIN_XX[img, :, :, 4])
ax4.imshow(TRAIN_XX[img, :, :, 5])
ax5.imshow(TRAIN_YY[img, :, :, 0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Validation split

# %%
from sklearn.model_selection import train_test_split

# Split the data
x_train, x_valid, y_train, y_valid = train_test_split(TRAIN_XX, TRAIN_YY, test_size=0.2, shuffle= True)

# %%
img=1546
fig,(ax1,ax2, ax3, ax4, ax5)= plt.subplots(1,5,figsize=(15,10))

ax1.set_title("RGB image")
ax2.set_title("NDVI")
ax3.set_title("Slope")
ax4.set_title("Elevation")
ax5.set_title("Mask")
ax1.imshow(x_train[img, :, :, 0:3])
ax2.imshow(x_train[img, :, :, 3])
ax3.imshow(x_train[img, :, :, 4])
ax4.imshow(x_train[img, :, :, 5])
ax5.imshow(y_train[img, :, :, 0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
x_train.shape, y_train.shape
# Out:
# ((3039, 128, 128, 6), (3039, 128, 128, 1))

# %%
# to release some memory, delete the unnecessary variable
del TRAIN_XX
del TRAIN_YY
del all_train
del all_mask

# %%
img=1546
fig,(ax1,ax2, ax3, ax4)= plt.subplots(1,4,figsize=(15,10))


ax1.set_title("RGB image")
ax2.set_title("NDVI")
ax3.set_title("SLOPE")
ax4.set_title("Mask")
ax1.imshow(x_train[img, :, :, 0:3])
ax2.imshow(x_train[img, :, :, 3])
ax3.imshow(x_train[img, :, :, 4])
ax4.imshow(y_train[img, :, :, 0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Unet Model

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# precision
def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

#f1 score
def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def unet_model(IMG_WIDTH, IMG_HIGHT, IMG_CHANNELS):
    inputs = tf.keras.layers.Input((IMG_WIDTH, IMG_HIGHT, IMG_CHANNELS))

    # Converted inputs to floating
    #s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)


    #Contraction path
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = tf.keras.layers.Dropout(0.1)(c1)
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = tf.keras.layers.Dropout(0.1)(c2)
    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = tf.keras.layers.Dropout(0.2)(c3)
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = tf.keras.layers.Dropout(0.2)(c4)
    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = tf.keras.layers.Dropout(0.3)(c5)
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path 
    u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = tf.keras.layers.Dropout(0.2)(c6)
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = tf.keras.layers.concatenate([u7, c3])
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = tf.keras.layers.Dropout(0.2)(c7)
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = tf.keras.layers.Dropout(0.1)(c8)
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
    c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = tf.keras.layers.Dropout(0.1)(c9)
    c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', f1_m, precision_m, recall_m])
    
    return model

# %%
from tensorflow.keras import backend as K

model = unet_model(128, 128, 6)
# model.summary()
checkpointer = tf.keras.callbacks.ModelCheckpoint("best_model.h5", monitor="val_f1_m", verbose=1, save_best_only=True, mode="max")
# earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_f1_m', patience=10, verbose=1, mode='max')

callbacks = [
    # earlyStopping,
    checkpointer
    ]
history = model.fit(x_train, y_train, batch_size=16,  
          epochs=30, 
          verbose = 2,
          validation_data=(x_valid, y_valid),
          callbacks=callbacks)

model.save("model_save.h5")
# Out:
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/30
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
#
# Epoch 1: val_f1_m improved from -inf to 0.59541, saving model to best_model.h5
# c:\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 190/190 - 101s - loss: 0.0679 - accuracy: 0.9748 - f1_m: 0.2457 - precision_m: 0.5384 - recall_m: 0.2115 - val_loss: 0.0430 - val_accuracy: 0.9835 - val_f1_m: 0.5954 - val_precision_m: 0.6425 - val_recall_m: 0.5751 - 101s/epoch - 534ms/step
# Epoch 2/30
#
# Epoch 2: val_f1_m did not improve from 0.59541
# 190/190 - 88s - loss: 0.0469 - accuracy: 0.9825 - f1_m: 0.5665 - precision_m: 0.6784 - recall_m: 0.5142 - val_loss: 0.0406 - val_accuracy: 0.9848 - val_f1_m: 0.5547 - val_precision_m: 0.7523 - val_recall_m: 0.4477 - 88s/epoch - 463ms/step
# Epoch 3/30
#
# Epoch 3: val_f1_m improved from 0.59541 to 0.62694, saving model to best_model.h5
# 190/190 - 91s - loss: 0.0413 - accuracy: 0.9845 - f1_m: 0.5970 - precision_m: 0.7290 - recall_m: 0.5239 - val_loss: 0.0364 - val_accuracy: 0.9856 - val_f1_m: 0.6269 - val_precision_m: 0.7156 - val_recall_m: 0.5720 - 91s/epoch - 477ms/step
# Epoch 4/30
#
# Epoch 4: val_f1_m improved from 0.62694 to 0.63191, saving model to best_model.h5
# 190/190 - 85s - loss: 0.0382 - accuracy: 0.9854 - f1_m: 0.6180 - precision_m: 0.7461 - recall_m: 0.5413 - val_loss: 0.0342 - val_accuracy: 0.9868 - val_f1_m: 0.6319 - val_precision_m: 0.7733 - val_recall_m: 0.5417 - 85s/epoch - 446ms/step
# Epoch 5/30
#
# Epoch 5: val_f1_m did not improve from 0.63191
# 190/190 - 97s - loss: 0.0361 - accuracy: 0.9860 - f1_m: 0.6377 - precision_m: 0.7656 - recall_m: 0.5592 - val_loss: 0.0367 - val_accuracy: 0.9863 - val_f1_m: 0.6222 - val_precision_m: 0.7583 - val_recall_m: 0.5378 - 97s/epoch - 510ms/step
# Epoch 6/30
#
# Epoch 6: val_f1_m improved from 0.63191 to 0.67422, saving model to best_model.h5
# 190/190 - 117s - loss: 0.0353 - accuracy: 0.9862 - f1_m: 0.6443 - precision_m: 0.7708 - recall_m: 0.5648 - val_loss: 0.0320 - val_accuracy: 0.9875 - val_f1_m: 0.6742 - val_precision_m: 0.7416 - val_recall_m: 0.6256 - 117s/epoch - 614ms/step
# Epoch 7/30
#
# Epoch 7: val_f1_m did not improve from 0.67422
# 190/190 - 93s - loss: 0.0351 - accuracy: 0.9864 - f1_m: 0.6446 - precision_m: 0.7759 - recall_m: 0.5673 - val_loss: 0.0324 - val_accuracy: 0.9875 - val_f1_m: 0.6477 - val_precision_m: 0.8012 - val_recall_m: 0.5505 - 93s/epoch - 490ms/step
# Epoch 8/30
#
# Epoch 8: val_f1_m did not improve from 0.67422
# 190/190 - 78s - loss: 0.0343 - accuracy: 0.9866 - f1_m: 0.6591 - precision_m: 0.7771 - recall_m: 0.5825 - val_loss: 0.0321 - val_accuracy: 0.9875 - val_f1_m: 0.6460 - val_precision_m: 0.8084 - val_recall_m: 0.5447 - 78s/epoch - 411ms/step
# Epoch 9/30
#
# Epoch 9: val_f1_m improved from 0.67422 to 0.68280, saving model to best_model.h5
# 190/190 - 81s - loss: 0.0338 - accuracy: 0.9867 - f1_m: 0.6556 - precision_m: 0.7729 - recall_m: 0.5837 - val_loss: 0.0303 - val_accuracy: 0.9880 - val_f1_m: 0.6828 - val_precision_m: 0.7636 - val_recall_m: 0.6235 - 81s/epoch - 424ms/step
# Epoch 10/30
#
# Epoch 10: val_f1_m improved from 0.68280 to 0.69814, saving model to best_model.h5
# 190/190 - 81s - loss: 0.0335 - accuracy: 0.9869 - f1_m: 0.6584 - precision_m: 0.7705 - recall_m: 0.5904 - val_loss: 0.0310 - val_accuracy: 0.9878 - val_f1_m: 0.6981 - val_precision_m: 0.7232 - val_recall_m: 0.6826 - 81s/epoch - 427ms/step
# Epoch 11/30
#
# Epoch 11: val_f1_m did not improve from 0.69814
# 190/190 - 80s - loss: 0.0332 - accuracy: 0.9870 - f1_m: 0.6614 - precision_m: 0.7752 - recall_m: 0.5910 - val_loss: 0.0296 - val_accuracy: 0.9883 - val_f1_m: 0.6926 - val_precision_m: 0.7639 - val_recall_m: 0.6409 - 80s/epoch - 423ms/step
# Epoch 12/30
#
# Epoch 12: val_f1_m did not improve from 0.69814
# 190/190 - 79s - loss: 0.0324 - accuracy: 0.9872 - f1_m: 0.6699 - precision_m: 0.7792 - recall_m: 0.6007 - val_loss: 0.0299 - val_accuracy: 0.9882 - val_f1_m: 0.6767 - val_precision_m: 0.7928 - val_recall_m: 0.5978 - 79s/epoch - 415ms/step
# Epoch 13/30
#
# Epoch 13: val_f1_m did not improve from 0.69814
# 190/190 - 86s - loss: 0.0319 - accuracy: 0.9874 - f1_m: 0.6739 - precision_m: 0.7825 - recall_m: 0.6017 - val_loss: 0.0311 - val_accuracy: 0.9877 - val_f1_m: 0.6543 - val_precision_m: 0.8061 - val_recall_m: 0.5580 - 86s/epoch - 451ms/step
# Epoch 14/30
#
# Epoch 14: val_f1_m did not improve from 0.69814
# 190/190 - 77s - loss: 0.0324 - accuracy: 0.9872 - f1_m: 0.6715 - precision_m: 0.7885 - recall_m: 0.5988 - val_loss: 0.0348 - val_accuracy: 0.9874 - val_f1_m: 0.6267 - val_precision_m: 0.8340 - val_recall_m: 0.5117 - 77s/epoch - 407ms/step
# Epoch 15/30
#
# Epoch 15: val_f1_m did not improve from 0.69814
# 190/190 - 78s - loss: 0.0315 - accuracy: 0.9875 - f1_m: 0.6782 - precision_m: 0.7807 - recall_m: 0.6102 - val_loss: 0.0310 - val_accuracy: 0.9882 - val_f1_m: 0.6774 - val_precision_m: 0.7933 - val_recall_m: 0.5991 - 78s/epoch - 410ms/step
# Epoch 16/30
#
# Epoch 16: val_f1_m did not improve from 0.69814
# 190/190 - 77s - loss: 0.0311 - accuracy: 0.9876 - f1_m: 0.6894 - precision_m: 0.7882 - recall_m: 0.6230 - val_loss: 0.0302 - val_accuracy: 0.9883 - val_f1_m: 0.6813 - val_precision_m: 0.7916 - val_recall_m: 0.6069 - 77s/epoch - 407ms/step
# Epoch 17/30
#
# Epoch 17: val_f1_m did not improve from 0.69814
# 190/190 - 76s - loss: 0.0313 - accuracy: 0.9877 - f1_m: 0.6852 - precision_m: 0.7878 - recall_m: 0.6161 - val_loss: 0.0305 - val_accuracy: 0.9880 - val_f1_m: 0.6591 - val_precision_m: 0.8246 - val_recall_m: 0.5556 - 76s/epoch - 402ms/step
# Epoch 18/30
#
# Epoch 18: val_f1_m did not improve from 0.69814
# 190/190 - 75s - loss: 0.0309 - accuracy: 0.9878 - f1_m: 0.6882 - precision_m: 0.7921 - recall_m: 0.6185 - val_loss: 0.0307 - val_accuracy: 0.9880 - val_f1_m: 0.6556 - val_precision_m: 0.8275 - val_recall_m: 0.5502 - 75s/epoch - 394ms/step
# Epoch 19/30
#
# Epoch 19: val_f1_m improved from 0.69814 to 0.70405, saving model to best_model.h5
# 190/190 - 75s - loss: 0.0313 - accuracy: 0.9877 - f1_m: 0.6866 - precision_m: 0.7899 - recall_m: 0.6178 - val_loss: 0.0306 - val_accuracy: 0.9881 - val_f1_m: 0.7040 - val_precision_m: 0.7323 - val_recall_m: 0.6866 - 75s/epoch - 397ms/step
# Epoch 20/30
#
# Epoch 20: val_f1_m did not improve from 0.70405
# 190/190 - 75s - loss: 0.0307 - accuracy: 0.9879 - f1_m: 0.6907 - precision_m: 0.7923 - recall_m: 0.6222 - val_loss: 0.0311 - val_accuracy: 0.9880 - val_f1_m: 0.6584 - val_precision_m: 0.8178 - val_recall_m: 0.5607 - 75s/epoch - 397ms/step
# Epoch 21/30
#
# Epoch 21: val_f1_m improved from 0.70405 to 0.70695, saving model to best_model.h5
# 190/190 - 75s - loss: 0.0305 - accuracy: 0.9879 - f1_m: 0.6943 - precision_m: 0.7915 - recall_m: 0.6292 - val_loss: 0.0296 - val_accuracy: 0.9883 - val_f1_m: 0.7070 - val_precision_m: 0.7421 - val_recall_m: 0.6823 - 75s/epoch - 395ms/step
# Epoch 22/30
#
# Epoch 22: val_f1_m did not improve from 0.70695
# 190/190 - 78s - loss: 0.0310 - accuracy: 0.9877 - f1_m: 0.6905 - precision_m: 0.7899 - recall_m: 0.6237 - val_loss: 0.0307 - val_accuracy: 0.9880 - val_f1_m: 0.6546 - val_precision_m: 0.8248 - val_recall_m: 0.5505 - 78s/epoch - 410ms/step
# Epoch 23/30
#
# Epoch 23: val_f1_m did not improve from 0.70695
# 190/190 - 77s - loss: 0.0304 - accuracy: 0.9880 - f1_m: 0.6930 - precision_m: 0.7892 - recall_m: 0.6260 - val_loss: 0.0310 - val_accuracy: 0.9881 - val_f1_m: 0.6608 - val_precision_m: 0.8272 - val_recall_m: 0.5578 - 77s/epoch - 404ms/step
# Epoch 24/30
#
# Epoch 24: val_f1_m did not improve from 0.70695
# 190/190 - 87s - loss: 0.0299 - accuracy: 0.9881 - f1_m: 0.6990 - precision_m: 0.7904 - recall_m: 0.6359 - val_loss: 0.0288 - val_accuracy: 0.9884 - val_f1_m: 0.6889 - val_precision_m: 0.7866 - val_recall_m: 0.6210 - 87s/epoch - 459ms/step
# Epoch 25/30
#
# Epoch 25: val_f1_m did not improve from 0.70695
# 190/190 - 90s - loss: 0.0293 - accuracy: 0.9883 - f1_m: 0.7077 - precision_m: 0.7934 - recall_m: 0.6469 - val_loss: 0.0298 - val_accuracy: 0.9883 - val_f1_m: 0.6924 - val_precision_m: 0.7651 - val_recall_m: 0.6407 - 90s/epoch - 474ms/step
# Epoch 26/30
#
# Epoch 26: val_f1_m did not improve from 0.70695
# 190/190 - 90s - loss: 0.0297 - accuracy: 0.9881 - f1_m: 0.6991 - precision_m: 0.7925 - recall_m: 0.6372 - val_loss: 0.0295 - val_accuracy: 0.9884 - val_f1_m: 0.6828 - val_precision_m: 0.7874 - val_recall_m: 0.6114 - 90s/epoch - 471ms/step
# Epoch 27/30
#
# Epoch 27: val_f1_m did not improve from 0.70695
# 190/190 - 90s - loss: 0.0290 - accuracy: 0.9884 - f1_m: 0.7045 - precision_m: 0.7929 - recall_m: 0.6424 - val_loss: 0.0291 - val_accuracy: 0.9885 - val_f1_m: 0.6973 - val_precision_m: 0.7779 - val_recall_m: 0.6404 - 90s/epoch - 472ms/step
# Epoch 28/30
#
# Epoch 28: val_f1_m did not improve from 0.70695
# 190/190 - 89s - loss: 0.0295 - accuracy: 0.9883 - f1_m: 0.7056 - precision_m: 0.7943 - recall_m: 0.6438 - val_loss: 0.0312 - val_accuracy: 0.9882 - val_f1_m: 0.6708 - val_precision_m: 0.8071 - val_recall_m: 0.5835 - 89s/epoch - 471ms/step
# Epoch 29/30
#
# Epoch 29: val_f1_m did not improve from 0.70695
# 190/190 - 91s - loss: 0.0291 - accuracy: 0.9884 - f1_m: 0.7113 - precision_m: 0.7957 - recall_m: 0.6520 - val_loss: 0.0310 - val_accuracy: 0.9882 - val_f1_m: 0.6680 - val_precision_m: 0.8196 - val_recall_m: 0.5731 - 91s/epoch - 476ms/step
# Epoch 30/30
#
# Epoch 30: val_f1_m did not improve from 0.70695
# 190/190 - 89s - loss: 0.0283 - accuracy: 0.9886 - f1_m: 0.7156 - precision_m: 0.7987 - recall_m: 0.6550 - val_loss: 0.0295 - val_accuracy: 0.9883 - val_f1_m: 0.7035 - val_precision_m: 0.7441 - val_recall_m: 0.6738 - 89s/epoch - 468ms/step

# %%
loss, accuracy, f1_score, precision, recall = model.evaluate(x_valid, y_valid, verbose=0)
print(loss, accuracy, f1_score, precision, recall)
# Out:
# 0.02953336387872696 0.988345205783844 0.7184858918190002 0.7590222954750061 0.6853707432746887

# %% [markdown]
# # Prediction

# %%
fig,((ax11,ax12),(ax13,ax14)) = plt.subplots(2,2,figsize=(20,15))
ax11.plot(history.history['loss'])
ax11.plot(history.history['val_loss'])
ax11.title.set_text('Unet model loss')
ax11.set_ylabel('loss')
ax11.set_xlabel('epoch')
ax11.legend(['train', 'validation'], loc='upper left')

ax12.plot(history.history['precision_m'])
ax12.plot(history.history['val_precision_m'])
ax12.set_title('Unet model precision')
ax12.set_ylabel('precision')
ax12.set_xlabel('epoch')
ax12.legend(['train', 'validation'], loc='upper left')

ax13.plot(history.history['recall_m'])
ax13.plot(history.history['val_recall_m'])
ax13.set_title('Unet model recall')
ax13.set_ylabel('recall')
ax13.set_xlabel('epoch')
ax13.legend(['train', 'validation'], loc='upper left')

ax14.plot(history.history['f1_m'])
ax14.plot(history.history['val_f1_m'])
ax14.set_title('Unet model f1')
ax14.set_ylabel('f1')
ax14.set_xlabel('epoch')
ax14.legend(['train', 'validation'], loc='upper left')

# %%
threshold = 0.5
pred_img = model.predict(x_valid)
pred_img = (pred_img > threshold).astype(np.uint8)
# Out:
# 24/24 [==============================] - 5s 200ms/step

# %%
img = 160
fig,(ax1,ax2,ax3)= plt.subplots(1,3,figsize=(15,10))
ax1.imshow(pred_img[img, :, :, 0])
ax1.set_title("Predictions")
ax2.imshow(y_valid[img, :, :, 0])
ax2.set_title("Label")
ax3.imshow(x_valid[img, :, :, 0:3])
ax3.set_title('Training Image')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Training Image')

# %% [markdown]
# # Validation data

# %%
validation_url = r'C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\\*.h5'
img_val = sorted(glob.glob(validation_url))

VAL_XX = np.zeros((245, 128, 128, 6))
mask_name = []
for i, img in enumerate(img_val):
    print(i, img)
    mask_name.append(img.split('/')[-1].replace('image', 'mask'))
    with h5py.File(img) as hdf:
        ls = list(hdf.keys())
        data = np.array(hdf.get('img'))

        # assign 0 for the nan value
        data[np.isnan(data)] = 0.000001

        # to normalize the data 
        mid_rgb = data[:, :, 1:4].max() / 2.0
        mid_slope = data[:, :, 12].max() / 2.0
        mid_elevation = data[:, :, 13].max() / 2.0

        # ndvi calculation
        data_red = data[:, :, 3]
        data_nir = data[:, :, 7]
        data_ndvi = np.divide(data_nir - data_red,np.add(data_nir, data_red))
        
        # final array
        VAL_XX[i, :, :, 0] = 1 - data[:, :, 3] / mid_rgb #RED
        VAL_XX[i, :, :, 1] = 1 - data[:, :, 2] / mid_rgb #GREEN
        VAL_XX[i, :, :, 2] = 1 - data[:, :, 1] / mid_rgb #BLUE
        VAL_XX[i, :, :, 3] = data_ndvi #NDVI
        VAL_XX[i, :, :, 4] = 1- data[:, :, 13] / mid_slope #SLOPE
        VAL_XX[i, :, :, 5] = 1 - data[:, :, 13] / mid_elevation #ELEVATION
# Out:
# 0 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image
C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_226.h5
# 142 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_227.h5
# 143 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_228.h5
# 144 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_229.h5
# 145 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_23.h5
# 146 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_230.h5
# 147 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_231.h5
# 148 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_232.h5
# 149 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_233.h5
# 150 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_234.h5
# 151 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_235.h5
# 152 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_236.h5
# 153 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_237.h5
# 154 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_238.h5
# 155 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_239.h5
# 156 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_24.h5
# 157 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_240.h5
# 158 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_241.h5
# 159 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_242.h5
# 160 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_243.h5
# 161 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_244.h5
# 162 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_245.h5
# 163 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_25.h5
# 164 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_26.h5
# C:\Users\myada\AppData\Local\Temp\ipykernel_19608\1280533386.py:24: RuntimeWarning: invalid value encountered in divide
#   data_ndvi = np.divide(data_nir - data_red,np.add(data_nir, data_red))
# 165 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_27.h5
# 166 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_28.h5
# 167 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_29.h5
# 168 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_3.h5
# 169 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_30.h5
# 170 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_31.h5
# 171 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_32.h5
# 172 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_33.h5
# 173 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_34.h5
# 174 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_35.h5
# 175 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_36.h5
# 176 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_37.h5
# 177 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_38.h5
# 178 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_39.h5
# 179 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_4.h5
# 180 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_40.h5
# 181 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_41.h5
# 182 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_42.h5
# 183 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_43.h5
# 184 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_44.h5
# 185 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_45.h5
# 186 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_46.h5
# 187 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_47.h5
# 188 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_48.h5
# 189 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_49.h5
# 190 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_5.h5
# 191 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_50.h5
# 192 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_51.h5
# 193 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_52.h5
# 194 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_53.h5
# 195 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_54.h5
# 196 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_55.h5
# 197 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_56.h5
# 198 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_57.h5
# 199 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_58.h5
# 200 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_59.h5
# 201 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_6.h5
# 202 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_60.h5
# 203 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_61.h5
# 204 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_62.h5
# 205 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_63.h5
# 206 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_64.h5
# 207 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_65.h5
# 208 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_66.h5
# 209 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_67.h5
# 210 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_68.h5
# 211 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_69.h5
# 212 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_7.h5
# 213 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_70.h5
# 214 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_71.h5
# 215 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_72.h5
# 216 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_73.h5
# 217 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_74.h5
# 218 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_75.h5
# 219 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_76.h5
# 220 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_77.h5
# 221 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_78.h5
# 222 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_79.h5
# 223 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_8.h5
# 224 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_80.h5
# 225 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_81.h5
# 226 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_82.h5
# 227 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_83.h5
# 228 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_84.h5
# 229 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_85.h5
# 230 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_86.h5
# 231 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_87.h5
# 232 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_88.h5
# 233 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_89.h5
# 234 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_9.h5
# 235 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_90.h5
# 236 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_91.h5
# 237 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_92.h5
# 238 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_93.h5
# 239 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_94.h5
# 240 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_95.h5
# 241 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_96.h5
# 242 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_97.h5
# 243 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_98.h5
# 244 C:\\Users\\myada\\OneDrive\\Desktop\\Satelite_Segmentation\\ValidData\\img\image_99.h5

# %% [markdown]
# ## Prediction for validation data

# %%
threshold = 0.5
pred_img = model.predict(VAL_XX)
pred_img = (pred_img > threshold).astype(np.uint8)
pred_img.shape
# Out:
# 8/8 [==============================] - 2s 197ms/step
# (245, 128, 128, 1)

# %% [markdown]
# ## Visualization of validation image

# %%
img = 144
fig,(ax1,ax2)= plt.subplots(1,2,figsize=(15,10))
ax1.imshow(pred_img[img, :, :, 0])
ax1.set_title("Predictions")
ax2.imshow(VAL_XX[img, :, :, 0:3])
ax2.set_title('Training Image')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Training Image')
